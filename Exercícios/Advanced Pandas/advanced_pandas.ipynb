# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas

import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.

# %%
# Run this code:

admissions = pd.read_csv('Admission_Predict.csv')
#to remove trailing spaces at the end of the column names
admissions.columns = admissions.columns.str.rstrip()

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
# Your code here:

admissions.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
# Your code here:

admissions.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
# Your code here:

admissions.set_index(admissions['Serial No.'])
# Out:
#             Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# Serial No.
# 1                    1        337          118                  4  4.5  4.5
# 2                    2        316          104                  3  3.0  3.5
# 3                    3        322          110                  3  3.5  2.5
# 4                    4        314          103                  2  2.0  3.0
# 5                    5        330          115                  5  4.5  3.0
# 6                    6        321          109                  3  3.0  4.0
# 7                    7        308          101                  2  3.0  4.0
# 8                    8        302          102                  1  2.0  1.5
# 9                    9        323          108                  3  3.5  3.0
# 10                  10        327          111                  4  4.0  4.5
# 11                  11        328          112                  4  4.0  4.5
# 12                  12        307          109                  3  4.0  3.0
# 13                  13        311          104                  3  3.5  2.0
# 14                  14        314          105                  3  3.5  2.5
# 15                  15        317          107                  3  4.0  3.0
# 16                  16        319          106                  3  4.0  3.0
# 17                  17        318          110                  3  4.0  3.0
# 18                  18        303          102                  3  3.5  3.0
# 19                  19        325          114                  4  3.0  2.0
# 20                  20        328          116                  5  5.0  5.0
# 21                  21        334          119                  5  5.0  4.5
# 22                  22        336          119                  5  4.0  3.5
# 23                  23        322          109                  5  4.5  3.5
# 24                  24        298           98                  2  1.5  2.5
# 25                  25        295           93                  1  2.0  2.0
# 26                  26        310           99                  2  1.5  2.0
# 27                  27        300           97                  2  3.0  3.0
# 28                  28        327          103                  3  4.0  4.0
# 29                  29        338          118                  4  3.0  4.5
# 30                  30        340          114                  5  4.0  4.0
# ...                ...        ...          ...                ...  ...  ...
# 356                356        310          103                  2  2.5  2.5
# 357                357        324          110                  3  3.5  3.0
# 358                358        336          119                  4  4.5  4.0
# 359                359        321          109                  3  3.0  3.0
# 360                360        315          105                  2  2.0  2.5
# 361                361        304          101                  2  2.0  2.5
# 362                362        297           96                  2  2.5  2.0
# 363                363        290          100                  1  1.5  2.0
# 364                364        303           98                  1  2.0  2.5
# 365                365        311           99                  1  2.5  3.0
# 366                366        322          104                  3  3.5  4.0
# 367                367        319          105                  3  3.0  3.5
# 368                368        324          110                  4  4.5  4.0
# 369                369        300          100                  3  3.0  3.5
# 370                370        340          113                  4  5.0  5.0
# 371                371        335          117                  5  5.0  5.0
# 372                372        302          101                  2  2.5  3.5
# 373                373        307          105                  2  2.0  3.5
# 374                374        296           97                  2  1.5  2.0
# 375                375        320          108                  3  3.5  4.0
# 376                376        314          102                  2  2.0  2.5
# 377                377        318          106                  3  2.0  3.0
# 378                378        326          112                  4  4.0  3.5
# 379                379        317          104                  2  3.0  3.0
# 380                380        329          111                  4  4.5  4.0
# 381                381        324          110                  3  3.5  3.5
# 382                382        325          107                  3  3.0  3.5
# 383                383        330          116                  4  5.0  4.5
# 384                384        312          103                  3  3.5  4.0
# 385                385        333          117                  4  5.0  4.0
#
#             CGPA  Research  Chance of Admit
# Serial No.
# 1           9.65         1             0.92
# 2           8.00         1             0.72
# 3           8.67         1             0.80
# 4           8.21         0             0.65
# 5           9.34         1             0.90
# 6           8.20         1             0.75
# 7           7.90         0             0.68
# 8           8.00         0             0.50
# 9           8.60         0             0.45
# 10          9.00         1             0.84
# 11          9.10         1             0.78
# 12          8.00         1             0.62
# 13          8.20         1             0.61
# 14          8.30         0             0.54
# 15          8.70         0             0.66
# 16          8.00         1             0.65
# 17          8.80         0             0.63
# 18          8.50         0             0.62
# 19          8.40         0             0.70
# 20          9.50         1             0.94
# 21          9.70         1             0.95
# 22          9.80         1             0.97
# 23          8.80         0             0.76
# 24          7.50         1             0.44
# 25          7.20         0             0.46
# 26          7.30         0             0.54
# 27          8.10         1             0.65
# 28          8.30         1             0.74
# 29          9.40         1             0.91
# 30          9.60         1             0.90
# ...          ...       ...              ...
# 356         8.24         0             0.72
# 357         9.22         1             0.89
# 358         9.62         1             0.95
# 359         8.54         1             0.79
# 360         7.65         0             0.39
# 361         7.66         0             0.38
# 362         7.43         0             0.34
# 363         7.56         0             0.47
# 364         7.65         0             0.56
# 365         8.43         1             0.71
# 366         8.84         1             0.78
# 367         8.67         1             0.73
# 368         9.15         1             0.82
# 369         8.26         0             0.62
# 370         9.74         1             0.96
# 371         9.82         1             0.96
# 372         7.96         0             0.46
# 373         8.10         0             0.53
# 374         7.80         0             0.49
# 375         8.44         1             0.76
# 376         8.24         0             0.64
# 377         8.65         0             0.71
# 378         9.12         1             0.84
# 379         8.76         0             0.77
# 380         9.23         1             0.89
# 381         9.04         1             0.82
# 382         9.11         1             0.84
# 383         9.45         1             0.91
# 384         8.78         0             0.67
# 385         9.66         1             0.95
#
# [385 rows x 9 columns]

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
# Your code here:

df = pd.DataFrame()
df['Index'] = admissions['GRE Score'].astype(str) + '-' + admissions['CGPA'].astype(str) 


df['Index'].unique().shape
# Out:
# (385,)

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
# Your code here:

admissions.set_index(df['Index'])
# Out:
#           Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR
# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
# Your code here:

admissions[(admissions['CGPA']>9)&(admissions['Research']==1)]['index'].count()
# Out:
# 101

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
# Your code here:

admissions[(admissions['CGPA']>9)&(admissions['SOP']<3.5)]['Chance of Admit'].mean()
# Out:
# 0.8019999999999999

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
def standardize(col):
    # This function takes a column from a dataframe and returns a standardized column by subtracting the column's mean
    # and dividing by the column's standard deviation.
    
    # Your code here:

    norm_col=(col-col.mean())/col.std()
    return norm_col

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
# Your code here:
admissions['CGPA_std'] = standardize(admissions['CGPA'])
admissions['GRE_std'] = standardize(admissions['GRE Score'])
admissions['LOR_std'] = standardize(admissions['LOR'])

# %%
admissions.head()
# Out:
#    index  Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# 0      0           1        337          118                  4  4.5  4.5
# 1      1           2        316          104                  3  3.0  3.5
# 2      2           3        322          110                  3  3.5  2.5
# 3      3           4        314          103                  2  2.0  3.0
# 4      4           5        330          115                  5  4.5  3.0
#
#    CGPA  Research  Chance of Admit  CGPA_std   GRE_std   LOR_std
# 0  9.65         1             0.92  1.747900  1.753381  1.191647
# 1  8.00         1             0.72 -0.991211 -0.063367  0.076740
# 2  8.67         1             0.80  0.121034  0.455704 -1.038166
# 3  8.21         0             0.65 -0.642597 -0.236391 -0.480713
# 4  9.34         1             0.90  1.233279  1.147798 -0.480713

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Run this code:

from random import choices
std_columns = ['CGPA_std', 'GRE_std', 'LOR_std']

decision_choice = choices(std_columns, k=admissions.shape[0])

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
# Your code here:


admissions['deciding_column'] = admissions.lookup(admissions.index, decision_choice)

# %% [markdown]
# Create a column called `decision` in the `admissions` dataframe. Assign 1 to this column if the value of `deciding_column` is greater than 0.8 and 0 otherwise.

# %%
# Your code here:

admissions['decision'] = [1 if i > 0.8 else 0 for i in admissions['deciding_column'] ]

# %% [markdown]
# How many applicants will be accepted to the program using the decision column? Compute the result below.

# %%
# Your code here:


len(admissions[admissions['decision'] == 1])
# Out:
# 86

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to `admissions.columns`.

# %%
# Your code here:

# remove non character symbols
# replace spaces with _
# change upper case to lower case


def treatCol(x):
    x = ''.join(e for e in x if (e.isalnum() or e.isspace()))
    x = x.lower()
    x = x.replace(' ', '_')
    return x


cols = admissions.columns


admissions.columns = (treatCol(i) for i in admissions.columns)

# %% [markdown]
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the `cut` function. Assign this new score to the variable `adjusted_gre`.

# %%
# Your code here:

admissions.loc[admissions['university_rating'] >= 4, 'adjusted_gre'] = admissions['gre_score']+10

admissions['adjusted_gre'] = pd.cut(admissions['adjusted_gre'],4)

# %%
admissions
# Out:
#      index  serial_no  gre_score  toefl_score  university_rating  sop  lor  \
# 0        0          1        337          118                  4  4.5  4.5
# 1        1          2        316          104                  3  3.0  3.5
# 2        2          3        322          110                  3  3.5  2.5
# 3        3          4        314          103                  2  2.0  3.0
# 4        4          5        330          115                  5  4.5  3.0
# 5        5          6        321          109                  3  3.0  4.0
# 6        6          7        308          101                  2  3.0  4.0
# 7        7          8        302          102                  1  2.0  1.5
# 8        8          9        323          108                  3  3.5  3.0
# 9        9         10        327          111                  4  4.0  4.5
# 10      10         11        328          112                  4  4.0  4.5
# 11      11         12        307          109                  3  4.0  3.0
# 12      12         13        311          104                  3  3.5  2.0
# 13      13         14        314          105                  3  3.5  2.5
# 14      14         15        317          107                  3  4.0  3.0
# 15      15         16        319          106                  3  4.0  3.0
# 16      16         17        318          110                  3  4.0  3.0
# 17      17         18        303          102                  3  3.5  3.0
# 18      18         19        325          114                  4  3.0  2.0
# 19      19         20        328          116                  5  5.0  5.0
# 20      20         21        334          119                  5  5.0  4.5
# 21      21         22        336          119                  5  4.0  3.5
# 22      22         23        322          109                  5  4.5  3.5
# 23      23         24        298           98                  2  1.5  2.5
# 24      24         25        295           93                  1  2.0  2.0
# 25      25         26        310           99                  2  1.5  2.0
# 26      26         27        300           97                  2  3.0  3.0
# 27      27         28        327          103                  3  4.0  4.0
# 28      28         29        338          118                  4  3.0  4.5
# 29      29         30        340          114                  5  4.0  4.0
# ..     ...        ...        ...          ...                ...  ...  ...
# 355    355        356        310          103                  2  2.5  2.5
# 356    356        357        324          110                  3  3.5  3.0
# 357    357        358        336          119                  4  4.5  4.0
# 358    358        359        321          109                  3  3.0  3.0
# 359    359        360        315          105                  2  2.0  2.5
# 360    360        361        304          101                  2  2.0  2.5
# 361    361        362        297           96                  2  2.5  2.0
# 362    362        363        290          100                  1  1.5  2.0
# 363    363        364        303           98                  1  2.0  2.5
# 364    364        365        311           99                  1  2.5  3.0
# 365    365        366        322          104                  3  3.5  4.0
# 366    366        367        319          105                  3  3.0  3.5
# 367    367        368        324          110                  4  4.5  4.0
# 368    368        369        300          100                  3  3.0  3.5
# 369    369        370        340          113                  4  5.0  5.0
# 370    370        371        335          117                  5  5.0  5.0
# 371    371        372        302          101                  2  2.5  3.5
# 372    372        373        307          105                  2  2.0  3.5
# 373    373        374        296           97                  2  1.5  2.0
# 374    374        375        320          108                  3  3.5  4.0
# 368  8.26         0             0.62 -0.559593 -1.447556  0.076740
# 369  9.74         1             0.96  1.897306  2.012916  1.749100
# 370  9.82         1             0.96  2.030111  1.580357  1.749100
# 371  7.96         0             0.46 -1.057614 -1.274533  0.076740
# 372  8.10         0             0.53 -0.825204 -0.841973  0.076740
# 373  7.80         0             0.49 -1.323224 -1.793603 -1.595619
# 374  8.44         1             0.76 -0.260781  0.282680  0.634193
# 375  8.24         0             0.64 -0.592795 -0.236391 -1.038166
# 376  8.65         0             0.71  0.087833  0.109657 -0.480713
# 377  9.12         1             0.84  0.868064  0.801751  0.076740
# 378  8.76         0             0.77  0.270440  0.023145 -0.480713
# 379  9.23         1             0.89  1.050671  1.061286  0.634193
# 380  9.04         1             0.82  0.735259  0.628727  0.076740
# 381  9.11         1             0.84  0.851463  0.715239  0.076740
# 382  9.45         1             0.91  1.415886  1.147798  1.191647
# 383  8.78         0             0.67  0.303641 -0.409414  0.634193
# 384  9.66         1             0.95  1.764500  1.407334  0.634193
#
#      decidingcolumn  decision    adjusted_gre
# 0          1.753381         1  (337.5, 350.0]
# 1         -0.063367         0             NaN
# 2         -1.038166         0             NaN
# 3         -0.236391         0             NaN
# 4         -0.480713         0  (337.5, 350.0]
# 5          0.634193         0             NaN
# 6         -0.755462         0             NaN
# 7         -1.274533         0             NaN
# 8          0.004829         0             NaN
# 9          1.191647         1  (325.0, 337.5]
# 10         0.974775         1  (337.5, 350.0]
# 11        -0.841973         0             NaN
# 12        -0.495926         0             NaN
# 13        -0.236391         0             NaN
# 14         0.023145         0             NaN
# 15         0.196168         0             NaN
# 16         0.336843         0             NaN
# 17        -1.188021         0             NaN
# 18        -1.595619         0  (325.0, 337.5]
# 19         1.498890         1  (337.5, 350.0]
# 20         1.191647         1  (337.5, 350.0]
# 21         0.076740         0  (337.5, 350.0]
# 22         0.455704         0  (325.0, 337.5]
# 23        -1.620580         0             NaN
# 24        -1.595619         0             NaN
# 25        -1.595619         0             NaN
# 26        -0.480713         0             NaN
# 27         0.888263         1             NaN
# 28         1.332883         1  (337.5, 350.0]
# 29         0.634193         0  (337.5, 350.0]
# ..              ...       ...             ...
# 355       -0.582438         0             NaN
# 356        1.034071         1             NaN
# 357        1.666869         1  (337.5, 350.0]
# 358       -0.094775         0             NaN
# 359       -1.038166         0             NaN
# 360       -1.038166         0             NaN
# 361       -1.937449         0             NaN
# 362       -1.595619         0             NaN
# 363       -1.188021         0             NaN
# 364       -0.277382         0             NaN
# 365        0.634193         0             NaN
# 366        0.121034         0             NaN
# 367        0.628727         0  (325.0, 337.5]
# 368        0.076740         0             NaN
# 369        1.897306         1  (337.5, 350.0]
# 370        2.030111         1  (337.5, 350.0]
# 371       -1.057614         0             NaN
# 372       -0.825204         0             NaN
# 373       -1.595619         0             NaN
# 374       -0.260781         0             NaN
# 375       -0.236391         0             NaN
# 376        0.109657         0             NaN
# 377        0.868064         1  (325.0, 337.5]
# 378        0.270440         0             NaN
# 379        0.634193         0  (337.5, 350.0]
# 380        0.076740         0             NaN
# 381        0.076740         0             NaN
# 382        1.147798         1  (337.5, 350.0]
# 383        0.634193         0             NaN
# 384        1.764500         1  (337.5, 350.0]
#
# [385 rows x 16 columns]
