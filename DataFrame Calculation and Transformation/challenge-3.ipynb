# %% [markdown]
# # Challenge 3
#
# In this challenge we will work on the `Orders.csv` data set in the previous [Subsetting and Descriptive Stats lab](../../lab-subsetting-and-descriptive-stats/your-code/main.ipynb). In your work you will apply the thinking process and workflow we showed you in Challenge 2.
#
# You are serving as a Business Intelligence Analyst at the headquarter of an international fashion goods chain store. Your boss today asked you to do two things for her:
#
# **First, identify two groups of customers from the data set.** The first group is **VIP Customers** whose **aggregated expenses** at your global chain stores are **above the 95th percentile** (aka. 0.95 quantile). The second group is **Preferred Customers** whose **aggregated expenses** are **between the 75th and 95th percentile**.
#
# **Second, identify which country has the most of your VIP customers, and which country has the most of your VIP+Preferred Customers combined.**

# %% [markdown]
# # Q1: How to identify VIP & Preferred Customers?
#
# We start by importing all the required libraries:

# %%
# import required libraries
import numpy as np
import pandas as pd

# %% [markdown]
# Next, import `Orders.csv` from the "subsetting" lab folder into a dataframe variable called `orders`. Print the head of `orders` to overview the data:

# %%
# enter your code here
orders = pd.read_csv("../../Subsetting and Descriptive Statistics/your-code/Orders.csv")
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %% [markdown]
# ---
#
# "Identify VIP and Preferred Customers" is the non-technical goal of your boss. You need to translate that goal into technical languages that data analysts use:
#
# ## How to label customers whose aggregated `amount_spent` is in a given quantile range?

# %% [markdown]
# We break down the main problem into several sub problems:
#
# #### Sub Problem 1: How to aggregate the  `amount_spent` for unique customers?
#
# #### Sub Problem 2: How to select customers whose aggregated `amount_spent` is in a given quantile range?
#
# #### Sub Problem 3: How to label selected customers as "VIP" or "Preferred"?
#
# *Note: If you want to break down the main problem in a different way, please feel free to revise the sub problems above.*
#
# Now in the workspace below, tackle each of the sub problems using the iterative problem solving workflow. Insert cells as necessary to write your codes and explain your steps.

# %%
# your code here
orders.groupby(['CustomerID','Country'])['amount_spent'].sum()
# Out:
# CustomerID  Country
# 12346       United Kingdom    77183.60
# 12347       Iceland            4310.00
# 12348       Finland            1797.24
# 12349       Italy              1757.55
# 12350       Norway              334.40
# 12352       Norway             2506.04
# 12353       Bahrain              89.00
# 12354       Spain              1079.40
# 12355       Bahrain             459.40
# 12356       Portugal           2811.43
# 12357       Switzerland        6207.67
# 12358       Austria            1168.06
# 12359       Cyprus             6372.58
# 12360       Austria            2662.06
# 12361       Belgium             189.90
# 12362       Belgium            5226.23
# 12363       Unspecified         552.00
# 12364       Belgium            1313.10
# 12365       Cyprus              641.38
# 12367       Denmark             168.90
# 12370       Austria             277.20
#             Cyprus             3268.49
# 12371       Switzerland        1887.96
# ...

# %%
norders = pd.DataFrame(orders.groupby(['CustomerID','Country'],as_index=False)['amount_spent'].sum())


norders['amount_spent'].describe()
# Out:
# count      4347.000000
# mean       2050.013320
# std        8980.103578
# min           0.000000
# 25%         307.430000
# 50%         671.960000
# 75%        1661.195000
# max      280206.020000
# Name: amount_spent, dtype: float64

# %%
#Ex: Para buscar customerIDs entre 75% e 95%

#75th and 95th 
#Above 95th

s5 = norders['amount_spent'].quantile(.75)
n5 = norders['amount_spent'].quantile(.95)
print(v5, cq)
norders[(norders['amount_spent']>= s5)&(norders['amount_spent']<= n5)].sort_values('amount_spent')
# Out:
# 1661.6400000000003 5840.181999999983
#       CustomerID         Country  amount_spent
# 1960       15024  United Kingdom       1661.33
# 2110       15214  United Kingdom       1661.44
# 517        13012  United Kingdom       1661.84
# 155        12530         Germany       1662.28
# 446        12912  United Kingdom       1662.30
# 2772       16115  United Kingdom       1667.97
# 3888       17656  United Kingdom       1674.69
# 618        13149  United Kingdom       1676.06
# 974        13647  United Kingdom       1678.12
# 3152       16638  United Kingdom       1680.72
# 928        13577  United Kingdom       1687.60
# 627        13162  United Kingdom       1688.29
# 242        12635         Germany       1689.18
# 3525       17152  United Kingdom       1689.50
# 2235       15380  United Kingdom       1690.26
# 3176       16671  United Kingdom       1692.27
# 3288       16813  United Kingdom       1692.98
# 2361       15549  United Kingdom       1693.26
# ...

# %%
#Ex: Para buscar customerIDs maiores que 95%

#75th and 95th 
#Above 95th

norders[(norders['amount_spent']> n5)].sort_values('amount_spent')
# Out:
#       CustomerID         Country  amount_spent
# 312        12720         Germany       5781.73
# 545        13050  United Kingdom       5836.86
# 900        13534  United Kingdom       5870.08
# 658        13209  United Kingdom       5891.61
# 1906       14944  United Kingdom       5900.25
# 1524       14415  United Kingdom       5900.28
# 1595       14505  United Kingdom       5905.64
# 2237       15382  United Kingdom       5955.71
# 1302       14101  United Kingdom       5976.79
# 738        13316  United Kingdom       5977.73
# 577        13097  United Kingdom       6010.42
# 243        12637          France       6021.90
# 1763       14735  United Kingdom       6065.69
# 2646       15939  United Kingdom       6115.01
# 3778       17509  United Kingdom       6115.14
# 810        13418  United Kingdom       6127.43
# 1274       14060  United Kingdom       6140.42
# 10         12357     Switzerland       6207.67
# 1272       14057  United Kingdom       6217.96
# ...

# %%
norders['CustomerGroup'] = np.NaN

# %%
norders['CustomerGroup'] = norders[(norders['amount_spent']<= n5) & (norders['amount_spent']>= s5)]['CustomerGroup'].replace(np.NaN,'Preferred Customers')

# %%
norders['CustomerGroup'].where( norders['amount_spent']<= n5,'VIP Customer', inplace=True)

# %%
print(s5,n5)
norders
# Out:
# 1661.1950000000002 5774.277999999997
#       CustomerID         Country  amount_spent        CustomerGroup
# 0          12346  United Kingdom      77183.60         VIP Customer
# 1          12347         Iceland       4310.00  Preferred Customers
# 2          12348         Finland       1797.24  Preferred Customers
# 3          12349           Italy       1757.55  Preferred Customers
# 4          12350          Norway        334.40                  NaN
# 5          12352          Norway       2506.04  Preferred Customers
# 6          12353         Bahrain         89.00                  NaN
# 7          12354           Spain       1079.40                  NaN
# 8          12355         Bahrain        459.40                  NaN
# 9          12356        Portugal       2811.43  Preferred Customers
# 10         12357     Switzerland       6207.67         VIP Customer
# 11         12358         Austria       1168.06                  NaN
# ...

# %% [markdown]
# Now we'll leave it to you to solve Q2 & Q3, which you can leverage from your solution for Q1:
#
# # Q2: How to identify which country has the most VIP Customers?
#
# # Q3: How to identify which country has the most VIP+Preferred Customers combined?
#
# Provide your solution for Q2 below:

# %%
# your code here
#Q2
norders[norders['CustomerGroup']==
        'VIP Customer'].groupby('Country')['CustomerGroup'].describe().sort_values('freq', ascending=False)
# Out:
#                 count unique           top freq
# Country
# United Kingdom    178      1  VIP Customer  178
# Germany            11      1  VIP Customer   11
# France              9      1  VIP Customer    9
# Switzerland         3      1  VIP Customer    3
# Spain               2      1  VIP Customer    2
# Portugal            2      1  VIP Customer    2
# Japan               2      1  VIP Customer    2
# EIRE                2      1  VIP Customer    2
# Finland             1      1  VIP Customer    1
# Channel Islands     1      1  VIP Customer    1
# Netherlands         1      1  VIP Customer    1
# Norway              1      1  VIP Customer    1
# Singapore           1      1  VIP Customer    1
# Denmark             1      1  VIP Customer    1
# Sweden              1      1  VIP Customer    1
# Cyprus              1      1  VIP Customer    1
# Australia           1      1  VIP Customer    1

# %%
# your code here
#Q2
norders[norders['CustomerGroup']==
        'Preferred Customers'].groupby('Country')['CustomerGroup'].describe().sort_values('freq', ascending=False)
# Out:
#                 count unique                  top freq
# Country
# United Kingdom    756      1  Preferred Customers  756
# Germany            28      1  Preferred Customers   28
# France             20      1  Preferred Customers   20
# Belgium            11      1  Preferred Customers   11
# Switzerland         6      1  Preferred Customers    6
# Norway              6      1  Preferred Customers    6
# Spain               5      1  Preferred Customers    5
# Portugal            5      1  Preferred Customers    5
# Italy               5      1  Preferred Customers    5
# Finland             4      1  Preferred Customers    4
# Australia           3      1  Preferred Customers    3
# Channel Islands     3      1  Preferred Customers    3
# Israel              2      1  Preferred Customers    2
# Japan               2      1  Preferred Customers    2
# Denmark             2      1  Preferred Customers    2
# Cyprus              2      1  Preferred Customers    2
# ...

# %%
# your code here
#Q3
norders.groupby('Country')['CustomerGroup'].count().sort_values(ascending=False)
# Out:
# Country
# United Kingdom          934
# Germany                  39
# France                   29
# Belgium                  11
# Switzerland               9
# Norway                    7
# Spain                     7
# Portugal                  7
# Italy                     5
# Finland                   5
# Channel Islands           4
# Japan                     4
# Australia                 4
# Cyprus                    3
# Denmark                   3
# EIRE                      3
# Sweden                    2
# Israel                    2
# Canada                    1
# Malta                     1
# Singapore                 1
# Netherlands               1
# Iceland                   1
# Poland                    1
# Lebanon                   1
# Austria                   1
# Greece                    1
# United Arab Emirates      0
# Bahrain                   0
# Brazil                    0
# European Community        0
# USA                       0
# Czech Republic            0
# ...
