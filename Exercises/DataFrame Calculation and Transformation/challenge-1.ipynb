# %%
# import libraries
import pandas as pd

# %% [markdown]
# ### Import data set
#
# Import data set `Pokemon.csv` from the `your-code` directory of this lab. Read the data into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# import data set
pokemon = pd.read_csv('Pokemon.csv')

# %% [markdown]
# ### Print first 10 rows of `pokemon`

# %%
# enter your code here
pokemon.head(13)
# Out:
#     #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0   1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1   2                    Ivysaur  Grass  Poison    405  60      62       63
# 2   3                   Venusaur  Grass  Poison    525  80      82       83
# 3   3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4   4                 Charmander   Fire     NaN    309  39      52       43
# 5   5                 Charmeleon   Fire     NaN    405  58      64       58
# 6   6                  Charizard   Fire  Flying    534  78      84       78
# 7   6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8   6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9   7                   Squirtle  Water     NaN    314  44      48       65
# 10  8                  Wartortle  Water     NaN    405  59      63       80
# 11  9                  Blastoise  Water     NaN    530  79      83      100
# 12  9    BlastoiseMega Blastoise  Water     NaN    630  79     103      120
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0        65       65     45           1      False
# 1        80       80     60           1      False
# 2       100      100     80           1      False
# 3       122      120     80           1      False
# 4        60       50     65           1      False
# 5        80       65     80           1      False
# 6       109       85    100           1      False
# 7       130       85    100           1      False
# 8       159      115    100           1      False
# 9        50       64     43           1      False
# 10       65       80     58           1      False
# 11       85      105     78           1      False
# 12      135      115     78           1      False

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# ### Obtain the distinct values across `Type 1` and `Type 2`
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
# enter your code here
# aqui ele empilha os dataframes - lembrando que deve ser a mesma quantidade de colunas para empilhar
types = pd.concat([pokemon['Type 1'],pokemon['Type 2']])

types.unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying', nan], dtype=object)

# %% [markdown]
# ### Cleanup `Name` that contain "Mega"
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
pokemon['PosMega'] = pokemon['Name'].str.find('Mega')

# %%
# enter your code here

#Código sem REGEX

def removeName(poke):
    
    p=0
    for i in range(poke['PosMega'].count()):
         
        if(poke.loc[i, ['PosMega']][0]!=-1):
            p = int(poke.loc[i, ['PosMega']][0])
            print('Pos',i, 'Car',p)  
            print(poke.loc[i, ['Name']][0])
            print(poke.loc[i, ['Name']][0][p:])
            poke.loc[i, ['Name']][0] = poke.loc[i, ['Name']][0][p:]
            print(poke.loc[i, ['Name']][0])
    return poke
removeName(pokemon)

pokemon

# test transformed data
# Out:
# Pos 3 Car 8
# VenusaurMega Venusaur
# Mega Venusaur
# VenusaurMega Venusaur
# Pos 7 Car 9
# CharizardMega Charizard X
# Mega Charizard X
# CharizardMega Charizard X
# Pos 8 Car 9
# CharizardMega Charizard Y
# Mega Charizard Y
# CharizardMega Charizard Y
# Pos 12 Car 9
# BlastoiseMega Blastoise
# Mega Blastoise
# BlastoiseMega Blastoise
# Pos 19 Car 8
# BeedrillMega Beedrill
# Mega Beedrill
# BeedrillMega Beedrill
# Pos 23 Car 7
# PidgeotMega Pidgeot
# Mega Pidgeot
# PidgeotMega Pidgeot
# Pos 71 Car 8
# AlakazamMega Alakazam
# Mega Alakazam
# AlakazamMega Alakazam
# Pos 87 Car 7
# SlowbroMega Slowbro
# Mega Slowbro
# SlowbroMega Slowbro
# Pos 102 Car 6
# GengarMega Gengar
# Mega Gengar
# GengarMega Gengar
# Pos 124 Car 10
# KangaskhanMega Kangaskhan
# Mega Kangaskhan
# KangaskhanMega Kangaskhan
# Pos 137 Car 6
# PinsirMega Pinsir
# Mega Pinsir
# PinsirMega Pinsir
# Pos 141 Car 8
# GyaradosMega Gyarados
# Mega Gyarados
# GyaradosMega Gyarados
# Pos 154 Car 10
# AerodactylMega Aerodactyl
# Mega Aerodactyl
# AerodactylMega Aerodactyl
# Pos 163 Car 6
# MewtwoMega Mewtwo X
# Mega Mewtwo X
# MewtwoMega Mewtwo X
# Pos 164 Car 6
# MewtwoMega Mewtwo Y
# Mega Mewtwo Y
# MewtwoMega Mewtwo Y
# Pos 168 Car 0
# Meganium
# Meganium
# Meganium
# Pos 196 Car 8
# AmpharosMega Ampharos
# Mega Ampharos
# AmpharosMega Ampharos
# Pos 224 Car 7
# SteelixMega Steelix
# Mega Steelix
# SteelixMega Steelix
# Pos 229 Car 6
# ScizorMega Scizor
# Mega Scizor
# ScizorMega Scizor
# Pos 232 Car 9
# HeracrossMega Heracross
# Mega Heracross
# HeracrossMega Heracross
# Pos 248 Car 8
# HoundoomMega Houndoom
# Mega Houndoom
# HoundoomMega Houndoom
# Pos 268 Car 9
# TyranitarMega Tyranitar
# Mega Tyranitar
# TyranitarMega Tyranitar
# Pos 275 Car 8
# SceptileMega Sceptile
# Mega Sceptile
# SceptileMega Sceptile
# Pos 279 Car 8
# BlazikenMega Blaziken
# Mega Blaziken
# BlazikenMega Blaziken
# Pos 283 Car 8
# SwampertMega Swampert
# Mega Swampert
# SwampertMega Swampert
# Pos 306 Car 9
# GardevoirMega Gardevoir
# Mega Gardevoir
# GardevoirMega Gardevoir
# Pos 327 Car 7
# SableyeMega Sableye
# Mega Sableye
# SableyeMega Sableye
# Pos 329 Car 6
# MawileMega Mawile
# Mega Mawile
# MawileMega Mawile
# Pos 333 Car 6
# AggronMega Aggron
# Mega Aggron
# AggronMega Aggron
# Pos 336 Car 8
# MedichamMega Medicham
# Mega Medicham
# MedichamMega Medicham
# Pos 339 Car 9
# ManectricMega Manectric
# Mega Manectric
# ManectricMega Manectric
# Pos 349 Car 8
# SharpedoMega Sharpedo
# Mega Sharpedo
# SharpedoMega Sharpedo
# Pos 354 Car 8
# CameruptMega Camerupt
# Mega Camerupt
# CameruptMega Camerupt
# Pos 366 Car 7
# AltariaMega Altaria
# Mega Altaria
# AltariaMega Altaria
# Pos 387 Car 7
# BanetteMega Banette
# Mega Banette
# BanetteMega Banette
# Pos 393 Car 5
# AbsolMega Absol
# Mega Absol
# AbsolMega Absol
# Pos 397 Car 6
# GlalieMega Glalie
# Mega Glalie
# GlalieMega Glalie
# Pos 409 Car 9
# SalamenceMega Salamence
# Mega Salamence
# SalamenceMega Salamence
# Pos 413 Car 9
# MetagrossMega Metagross
# Mega Metagross
# MetagrossMega Metagross
# Pos 418 Car 6
# LatiasMega Latias
# Mega Latias
# LatiasMega Latias
# Pos 420 Car 6
# LatiosMega Latios
# Mega Latios
# LatiosMega Latios
# Pos 426 Car 8
# RayquazaMega Rayquaza
# Mega Rayquaza
# RayquazaMega Rayquaza
# Pos 476 Car 7
# LopunnyMega Lopunny
# Mega Lopunny
# LopunnyMega Lopunny
# Pos 494 Car 8
# GarchompMega Garchomp
# Mega Garchomp
# GarchompMega Garchomp
# Pos 498 Car 7
# LucarioMega Lucario
# Mega Lucario
# LucarioMega Lucario
# Pos 511 Car 9
# AbomasnowMega Abomasnow
# Mega Abomasnow
# AbomasnowMega Abomasnow
# Pos 527 Car 7
# GalladeMega Gallade
# Mega Gallade
# GalladeMega Gallade
# Pos 591 Car 6
# AudinoMega Audino
# Mega Audino
# AudinoMega Audino
# Pos 796 Car 7
# DiancieMega Diancie
# Mega Diancie
# DiancieMega Diancie
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass  Poison    318   45      49
# 1      2                    Ivysaur     Grass  Poison    405   60      62
# 2      3                   Venusaur     Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4      4                 Charmander      Fire     NaN    309   39      52
# 5      5                 Charmeleon      Fire     NaN    405   58      64
# 6      6                  Charizard      Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9      7                   Squirtle     Water     NaN    314   44      48
# 10     8                  Wartortle     Water     NaN    405   59      63
# 11     9                  Blastoise     Water     NaN    530   79      83
# 12     9    BlastoiseMega Blastoise     Water     NaN    630   79     103
# 13    10                   Caterpie       Bug     NaN    195   45      30
# 14    11                    Metapod       Bug     NaN    205   50      20
# 15    12                 Butterfree       Bug  Flying    395   60      45
# 16    13                     Weedle       Bug  Poison    195   40      35
# 17    14                     Kakuna       Bug  Poison    205   45      25
# 18    15                   Beedrill       Bug  Poison    395   65      90
# 19    15      BeedrillMega Beedrill       Bug  Poison    495   65     150
# 20    16                     Pidgey    Normal  Flying    251   40      45
# 21    17                  Pidgeotto    Normal  Flying    349   63      60
# 22    18                    Pidgeot    Normal  Flying    479   83      80
# 23    18        PidgeotMega Pidgeot    Normal  Flying    579   83      80
# 24    19                    Rattata    Normal     NaN    253   30      56
# 25    20                   Raticate    Normal     NaN    413   55      81
# 26    21                    Spearow    Normal  Flying    262   40      60
# 27    22                     Fearow    Normal  Flying    442   65      90
# 28    23                      Ekans    Poison     NaN    288   35      60
# 29    24                      Arbok    Poison     NaN    438   60      85
# ..   ...                        ...       ...     ...    ...  ...     ...
# 770  700                    Sylveon     Fairy     NaN    525   95      65
# 771  701                   Hawlucha  Fighting  Flying    500   78      92
# 772  702                    Dedenne  Electric   Fairy    431   67      58
# 773  703                    Carbink      Rock   Fairy    500   50      50
# 774  704                      Goomy    Dragon     NaN    300   45      50
# 775  705                    Sliggoo    Dragon     NaN    452   68      75
# 776  706                     Goodra    Dragon     NaN    600   90     100
# 777  707                     Klefki     Steel   Fairy    470   57      80
# 778  708                   Phantump     Ghost   Grass    309   43      70
# 779  709                  Trevenant     Ghost   Grass    474   85     110
# 780  710      PumpkabooAverage Size     Ghost   Grass    335   49      66
# 781  710        PumpkabooSmall Size     Ghost   Grass    335   44      66
# 782  710        PumpkabooLarge Size     Ghost   Grass    335   54      66
# 783  710        PumpkabooSuper Size     Ghost   Grass    335   59      66
# 784  711      GourgeistAverage Size     Ghost   Grass    494   65      90
# 785  711        GourgeistSmall Size     Ghost   Grass    494   55      85
# 786  711        GourgeistLarge Size     Ghost   Grass    494   75      95
# 787  711        GourgeistSuper Size     Ghost   Grass    494   85     100
# 788  712                   Bergmite       Ice     NaN    304   55      69
# 789  713                    Avalugg       Ice     NaN    514   95     117
# 790  714                     Noibat    Flying  Dragon    245   40      30
# 791  715                    Noivern    Flying  Dragon    535   85      70
# 792  716                    Xerneas     Fairy     NaN    680  126     131
# 793  717                    Yveltal      Dark  Flying    680  126     131
# 794  718           Zygarde50% Forme    Dragon  Ground    600  108     100
# 795  719                    Diancie      Rock   Fairy    600   50     100
# 796  719        DiancieMega Diancie      Rock   Fairy    700   50     160
# 797  720        HoopaHoopa Confined   Psychic   Ghost    600   80     110
# 798  720         HoopaHoopa Unbound   Psychic    Dark    680   80     160
# 799  721                  Volcanion      Fire   Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  PosMega
# 0         49       65       65     45           1      False       -1
# 1         63       80       80     60           1      False       -1
# 2         83      100      100     80           1      False       -1
# 3        123      122      120     80           1      False        8
# 4         43       60       50     65           1      False       -1
# 5         58       80       65     80           1      False       -1
# 6         78      109       85    100           1      False       -1
# 7        111      130       85    100           1      False        9
# 8         78      159      115    100           1      False        9
# 9         65       50       64     43           1      False       -1
# 10        80       65       80     58           1      False       -1
# 11       100       85      105     78           1      False       -1
# 12       120      135      115     78           1      False        9
# 13        35       20       20     45           1      False       -1
# 14        55       25       25     30           1      False       -1
# 15        50       90       80     70           1      False       -1
# 16        30       20       20     50           1      False       -1
# 17        50       25       25     35           1      False       -1
# 18        40       45       80     75           1      False       -1
# 19        40       15       80    145           1      False        8
# 20        40       35       35     56           1      False       -1
# 21        55       50       50     71           1      False       -1
# 22        75       70       70    101           1      False       -1
# 23        80      135       80    121           1      False        7
# 24        35       25       35     72           1      False       -1
# 25        60       50       70     97           1      False       -1
# 26        30       31       31     70           1      False       -1
# 27        65       61       61    100           1      False       -1
# 28        44       40       54     55           1      False       -1
# 29        69       65       79     80           1      False       -1
# ..       ...      ...      ...    ...         ...        ...      ...
# 770       65      110      130     60           6      False       -1
# 771       75       74       63    118           6      False       -1
# 772       57       81       67    101           6      False       -1
# 773      150       50      150     50           6      False       -1
# 774       35       55       75     40           6      False       -1
# 775       53       83      113     60           6      False       -1
# 776       70      110      150     80           6      False       -1
# 777       91       80       87     75           6      False       -1
# 778       48       50       60     38           6      False       -1
# 779       76       65       82     56           6      False       -1
# 780       70       44       55     51           6      False       -1
# 781       70       44       55     56           6      False       -1
# 782       70       44       55     46           6      False       -1
# 783       70       44       55     41           6      False       -1
# 784      122       58       75     84           6      False       -1
# 785      122       58       75     99           6      False       -1
# 786      122       58       75     69           6      False       -1
# 787      122       58       75     54           6      False       -1
# 788       85       32       35     28           6      False       -1
# 789      184       44       46     28           6      False       -1
# 790       35       45       40     55           6      False       -1
# 791       80       97       80    123           6      False       -1
# 792       95      131       98     99           6       True       -1
# 793       95      131       98     99           6       True       -1
# 794      121       81       95     95           6       True       -1
# 795      150      100      150     50           6       True       -1
# 796      110      160      110    110           6       True        7
# 797       60      150      130     70           6       True       -1
# 798       60      170      130     80           6       True       -1
# 799      120      130       90     70           6       True       -1
#
# [800 rows x 14 columns]

# %%
pokemon['Name'] = pokemon['Name'].str.replace('.*(?=Mega)', "")

# %%
pokemon.head()
# Out:
#    #           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3       Venusaur  Grass  Poison    525  80      82       83      100
# 3  3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4     Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  PosMega
# 0       65     45           1      False       -1
# 1       80     60           1      False       -1
# 2      100     80           1      False       -1
# 3      120     80           1      False        8
# 4       50     65           1      False       -1

# %% [markdown]
# ### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
# enter your code here
pokemon['A/D Ratio'] = pokemon['Attack']/pokemon['Defense']
pokemon.head()
# Out:
#    #           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3       Venusaur  Grass  Poison    525  80      82       83      100
# 3  3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4     Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary    Combo_Type  A/D Ratio
# 0       65     45           1      False  Grass-Poison   1.000000
# 1       80     60           1      False  Grass-Poison   0.984127
# 2      100     80           1      False  Grass-Poison   0.987952
# 3      120     80           1      False  Grass-Poison   0.813008
# 4       50     65           1      False          Fire   1.209302

# %% [markdown]
# ### Identify the pokemon with the highest `A/D Ratio`

# %%
# enter your code here
pokemon.sort_values('A/D Ratio', ascending = False).head(1)
# Out:
#        #                Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic    NaN    600  50     180       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary Combo_Type  A/D Ratio
# 429      180       20    150           3       True    Psychic        9.0

# %% [markdown]
# ### Identify the pokemon with the lowest A/D Ratio

# %%
# enter your code here
pokemon.sort_values('A/D Ratio', ascending = True).head(1)
# Out:
#        #     Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213  Shuckle    Bug   Rock    505  20      10      230       10      230
#
#      Speed  Generation  Legendary Combo_Type  A/D Ratio
# 230      5           2      False   Bug-Rock   0.043478

# %% [markdown]
# ### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
# enter your code here


pokemon["Combo_Type"] = pokemon["Type 1"] + '-' + pokemon["Type 2"]
pokemon["Combo_Type"].fillna(pokemon["Type 1"], inplace=True)

pokemon
# Out:
#        #                   Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1              Bulbasaur     Grass  Poison    318   45      49
# 1      2                Ivysaur     Grass  Poison    405   60      62
# 2      3               Venusaur     Grass  Poison    525   80      82
# 3      3          Mega Venusaur     Grass  Poison    625   80     100
# 4      4             Charmander      Fire     NaN    309   39      52
# 5      5             Charmeleon      Fire     NaN    405   58      64
# 6      6              Charizard      Fire  Flying    534   78      84
# 7      6       Mega Charizard X      Fire  Dragon    634   78     130
# 8      6       Mega Charizard Y      Fire  Flying    634   78     104
# 9      7               Squirtle     Water     NaN    314   44      48
# 10     8              Wartortle     Water     NaN    405   59      63
# 11     9              Blastoise     Water     NaN    530   79      83
# 12     9         Mega Blastoise     Water     NaN    630   79     103
# 13    10               Caterpie       Bug     NaN    195   45      30
# 14    11                Metapod       Bug     NaN    205   50      20
# 15    12             Butterfree       Bug  Flying    395   60      45
# 16    13                 Weedle       Bug  Poison    195   40      35
# 17    14                 Kakuna       Bug  Poison    205   45      25
# 18    15               Beedrill       Bug  Poison    395   65      90
# 19    15          Mega Beedrill       Bug  Poison    495   65     150
# 20    16                 Pidgey    Normal  Flying    251   40      45
# 21    17              Pidgeotto    Normal  Flying    349   63      60
# 22    18                Pidgeot    Normal  Flying    479   83      80
# 23    18           Mega Pidgeot    Normal  Flying    579   83      80
# 24    19                Rattata    Normal     NaN    253   30      56
# 25    20               Raticate    Normal     NaN    413   55      81
# 26    21                Spearow    Normal  Flying    262   40      60
# 27    22                 Fearow    Normal  Flying    442   65      90
# 28    23                  Ekans    Poison     NaN    288   35      60
# 29    24                  Arbok    Poison     NaN    438   60      85
# ..   ...                    ...       ...     ...    ...  ...     ...
# 770  700                Sylveon     Fairy     NaN    525   95      65
# 771  701               Hawlucha  Fighting  Flying    500   78      92
# 772  702                Dedenne  Electric   Fairy    431   67      58
# 773  703                Carbink      Rock   Fairy    500   50      50
# 774  704                  Goomy    Dragon     NaN    300   45      50
# 775  705                Sliggoo    Dragon     NaN    452   68      75
# 776  706                 Goodra    Dragon     NaN    600   90     100
# 777  707                 Klefki     Steel   Fairy    470   57      80
# 778  708               Phantump     Ghost   Grass    309   43      70
# 779  709              Trevenant     Ghost   Grass    474   85     110
# 780  710  PumpkabooAverage Size     Ghost   Grass    335   49      66
# 781  710    PumpkabooSmall Size     Ghost   Grass    335   44      66
# 782  710    PumpkabooLarge Size     Ghost   Grass    335   54      66
# 783  710    PumpkabooSuper Size     Ghost   Grass    335   59      66
# 784  711  GourgeistAverage Size     Ghost   Grass    494   65      90
# 785  711    GourgeistSmall Size     Ghost   Grass    494   55      85
# 786  711    GourgeistLarge Size     Ghost   Grass    494   75      95
# 787  711    GourgeistSuper Size     Ghost   Grass    494   85     100
# 788  712               Bergmite       Ice     NaN    304   55      69
# 789  713                Avalugg       Ice     NaN    514   95     117
# 790  714                 Noibat    Flying  Dragon    245   40      30
# 791  715                Noivern    Flying  Dragon    535   85      70
# 792  716                Xerneas     Fairy     NaN    680  126     131
# 793  717                Yveltal      Dark  Flying    680  126     131
# 794  718       Zygarde50% Forme    Dragon  Ground    600  108     100
# 795  719                Diancie      Rock   Fairy    600   50     100
# 796  719           Mega Diancie      Rock   Fairy    700   50     160
# 797  720    HoopaHoopa Confined   Psychic   Ghost    600   80     110
# 798  720     HoopaHoopa Unbound   Psychic    Dark    680   80     160
# 799  721              Volcanion      Fire   Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary       Combo_Type  \
# 0         49       65       65     45           1      False     Grass-Poison
# 1         63       80       80     60           1      False     Grass-Poison
# 2         83      100      100     80           1      False     Grass-Poison
# 3        123      122      120     80           1      False     Grass-Poison
# 4         43       60       50     65           1      False             Fire
# 5         58       80       65     80           1      False             Fire
# 6         78      109       85    100           1      False      Fire-Flying
# 7        111      130       85    100           1      False      Fire-Dragon
# 8         78      159      115    100           1      False      Fire-Flying
# 9         65       50       64     43           1      False            Water
# 10        80       65       80     58           1      False            Water
# 11       100       85      105     78           1      False            Water
# 12       120      135      115     78           1      False            Water
# 13        35       20       20     45           1      False              Bug
# 14        55       25       25     30           1      False              Bug
# 15        50       90       80     70           1      False       Bug-Flying
# 16        30       20       20     50           1      False       Bug-Poison
# 17        50       25       25     35           1      False       Bug-Poison
# 18        40       45       80     75           1      False       Bug-Poison
# 19        40       15       80    145           1      False       Bug-Poison
# 20        40       35       35     56           1      False    Normal-Flying
# 21        55       50       50     71           1      False    Normal-Flying
# 22        75       70       70    101           1      False    Normal-Flying
# 23        80      135       80    121           1      False    Normal-Flying
# 24        35       25       35     72           1      False           Normal
# 25        60       50       70     97           1      False           Normal
# 26        30       31       31     70           1      False    Normal-Flying
# 27        65       61       61    100           1      False    Normal-Flying
# 28        44       40       54     55           1      False           Poison
# 29        69       65       79     80           1      False           Poison
# ..       ...      ...      ...    ...         ...        ...              ...
# 770       65      110      130     60           6      False            Fairy
# 771       75       74       63    118           6      False  Fighting-Flying
# 772       57       81       67    101           6      False   Electric-Fairy
# 773      150       50      150     50           6      False       Rock-Fairy
# 774       35       55       75     40           6      False           Dragon
# 775       53       83      113     60           6      False           Dragon
# 776       70      110      150     80           6      False           Dragon
# 777       91       80       87     75           6      False      Steel-Fairy
# 778       48       50       60     38           6      False      Ghost-Grass
# 779       76       65       82     56           6      False      Ghost-Grass
# 780       70       44       55     51           6      False      Ghost-Grass
# 781       70       44       55     56           6      False      Ghost-Grass
# 782       70       44       55     46           6      False      Ghost-Grass
# 783       70       44       55     41           6      False      Ghost-Grass
# 784      122       58       75     84           6      False      Ghost-Grass
# 785      122       58       75     99           6      False      Ghost-Grass
# 786      122       58       75     69           6      False      Ghost-Grass
# 787      122       58       75     54           6      False      Ghost-Grass
# 788       85       32       35     28           6      False              Ice
# 789      184       44       46     28           6      False              Ice
# 790       35       45       40     55           6      False    Flying-Dragon
# 791       80       97       80    123           6      False    Flying-Dragon
# 792       95      131       98     99           6       True            Fairy
# 793       95      131       98     99           6       True      Dark-Flying
# 794      121       81       95     95           6       True    Dragon-Ground
# 795      150      100      150     50           6       True       Rock-Fairy
# 796      110      160      110    110           6       True       Rock-Fairy
# 797       60      150      130     70           6       True    Psychic-Ghost
# 798       60      170      130     80           6       True     Psychic-Dark
# 799      120      130       90     70           6       True       Fire-Water
#
#      A/D Ratio
# 0     1.000000
# 1     0.984127
# 2     0.987952
# 3     0.813008
# 4     1.209302
# 5     1.103448
# 6     1.076923
# 7     1.171171
# 8     1.333333
# 9     0.738462
# 10    0.787500
# 11    0.830000
# 12    0.858333
# 13    0.857143
# 14    0.363636
# 15    0.900000
# 16    1.166667
# 17    0.500000
# 18    2.250000
# 19    3.750000
# 20    1.125000
# 21    1.090909
# 22    1.066667
# 23    1.000000
# 24    1.600000
# 25    1.350000
# 26    2.000000
# 27    1.384615
# 28    1.363636
# 29    1.231884
# ..         ...
# 770   1.000000
# 771   1.226667
# 772   1.017544
# 773   0.333333
# 774   1.428571
# 775   1.415094
# 776   1.428571
# 777   0.879121
# 778   1.458333
# 779   1.447368
# 780   0.942857
# 781   0.942857
# 782   0.942857
# 783   0.942857
# 784   0.737705
# 785   0.696721
# 786   0.778689
# 787   0.819672
# 788   0.811765
# 789   0.635870
# 790   0.857143
# 791   0.875000
# 792   1.378947
# 793   1.378947
# 794   0.826446
# 795   0.666667
# 796   1.454545
# 797   1.833333
# 798   2.666667
# 799   0.916667
#
# [800 rows x 15 columns]

# %%
#Sem tipos repetidos 
pokemon[pokemon['Type 1']==pokemon['Type 2']]["Combo_Type"]
# Out:
# Series([], Name: Combo_Type, dtype: object)

# %% [markdown]
# ### Identify the pokemons whose `A/D Ratio` are among the top 5

# %%
# enter your code here
pokemon.sort_values('A/D Ratio', ascending = False).head(6)
# Out:
#        #                Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic     NaN    600  50     180       20
# 347  318            Carvanha    Water    Dark    305  45      90       20
# 19    15       Mega Beedrill      Bug  Poison    495  65     150       40
# 453  408            Cranidos     Rock     NaN    350  67     125       40
# 348  319            Sharpedo    Water    Dark    460  70     120       40
# 428  386  DeoxysNormal Forme  Psychic     NaN    600  50     150       50
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Combo_Type  A/D Ratio
# 429      180       20    150           3       True     Psychic      9.000
# 347       65       20     65           3      False  Water-Dark      4.500
# 19        15       80    145           1      False  Bug-Poison      3.750
# 453       30       30     58           4      False        Rock      3.125
# 348       95       40     95           3      False  Water-Dark      3.000
# 428      150       50    150           3       True     Psychic      3.000

# %% [markdown]
# ### For the 5 pokemons printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemons with the highest `A/D Ratio`.

# %%
# enter your code here


ls = (pokemon.sort_values('A/D Ratio', ascending = False).head(6))['Combo_Type'].unique()
print(ls)
# Out:
# ['Psychic' 'Water-Dark' 'Bug-Poison' 'Rock']

# %% [markdown]
# ### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemons.
#
# Your output should look like below:
#
# ![Aggregate](aggregated-mean.png)

# %%
# enter your code here

pokemon[pokemon['Combo_Type'].isin(ls)].groupby('Combo_Type').mean()
# Out:
#                      #       Total         HP      Attack     Defense  \
# Combo_Type
# Bug-Poison  199.166667  347.916667  53.750000   68.333333   58.083333
# Psychic     381.973684  464.552632  72.552632   64.947368   67.236842
# Rock        410.111111  409.444444  67.111111  103.333333  107.222222
# Water-Dark  347.666667  493.833333  69.166667  120.000000   65.166667
#
#               Sp. Atk    Sp. Def      Speed  Generation  Legendary  A/D Ratio
# Combo_Type
# Bug-Poison  42.500000  59.333333  65.916667    2.333333   0.000000   1.315989
# Psychic     98.552632  82.394737  78.868421    3.342105   0.236842   1.164196
# Rock        40.555556  58.333333  32.888889    3.888889   0.111111   1.260091
# Water-Dark  88.833333  63.500000  87.166667    3.166667   0.000000   2.291949
